# %%
from pydub import AudioSegment
import pandas as pd

def splice_audio(audio_file, labels_file, output_dir, clip_duration=2):    
    # Load audio file
    audio = AudioSegment.from_wav(audio_file)
    
    # Read labels file into pandas DataFrame
    labels_df = pd.read_csv(labels_file, delimiter='\t', header=None, names=['start', 'end', 'label'])
    
    # Convert time to milliseconds
    labels_df['start_ms'] = (labels_df['start'] * 1000).astype(int)
    labels_df['end_ms'] = (labels_df['end'] * 1000).astype(int)
    
    # Splice audio clips
    for idx, row in labels_df.iterrows():
        for i in range(0, 2001, 50):
            start_ms = row['start_ms'] + i  # Adjust start time
            end_ms = row['start_ms'] + (2000+i)      # Adjust end time
            if start_ms < 0:
                start_ms = 0
            if end_ms > row['end_ms']:
                break;
            if (end_ms - start_ms) < 2000:
                break;
        
            clip = audio[start_ms:end_ms]
            output_file = f"{output_dir}/1{audio_file}_noswall_splice_{idx}_{i/100}.wav"
            clip.export(output_file, format="wav")
            print(f"Exported clip {idx} to {output_file}")


# Example usage
audio_file = "lawn_mower_test.wav"
labels_file = "001-1-5mth-breastfeeding-labels-vkidwel1noswalls.txt"
output_dir = "output_clips_lawn"
splice_audio(audio_file, labels_file, output_dir)
# Out:
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_0.0.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_0.5.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_1.0.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_1.5.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_2.0.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_2.5.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_3.0.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_3.5.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_4.0.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_4.5.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_5.0.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_5.5.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_6.0.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_6.5.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_7.0.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_7.5.wav
# Exported clip 0 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_0_8.0.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_0.0.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_0.5.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_1.0.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_1.5.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_2.0.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_2.5.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_3.0.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_3.5.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_4.0.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_4.5.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_5.0.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_5.5.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_6.0.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_6.5.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_7.0.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_7.5.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_8.0.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_8.5.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_9.0.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_9.5.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_10.0.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_10.5.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_11.0.wav
# Exported clip 2 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_2_11.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_0.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_0.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_1.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_1.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_2.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_2.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_3.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_3.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_4.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_4.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_5.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_5.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_6.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_6.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_7.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_7.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_8.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_8.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_9.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_9.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_10.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_10.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_11.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_11.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_12.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_12.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_13.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_13.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_14.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_14.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_15.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_15.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_16.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_16.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_17.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_17.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_18.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_18.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_19.0.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_19.5.wav
# Exported clip 5 to output_clips_lawn/1lawn_mower_test.wav_noswall_splice_5_20.0.wav
