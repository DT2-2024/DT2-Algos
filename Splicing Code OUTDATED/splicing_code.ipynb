# %%
from pydub import AudioSegment
import pandas as pd

def splice_audio(audio_file, labels_file, output_dir, clip_duration=2):    
    # Load audio file
    audio = AudioSegment.from_wav(audio_file)
    
    # Read labels file into pandas DataFrame
    labels_df = pd.read_csv(labels_file, delimiter='\t', header=None, names=['start', 'end', 'label'])
    
    # Convert time to milliseconds
    labels_df['start_ms'] = (labels_df['start'] * 1000).astype(int)
    labels_df['end_ms'] = (labels_df['end'] * 1000).astype(int)
    
    # Splice audio clips
    for idx, row in labels_df.iterrows():
        for i in range(0, 2001, 100):
            start_ms = row['start_ms'] - i  # Adjust start time
            end_ms = row['end_ms'] + (2000-i)      # Adjust end time
            if start_ms < 0:
                start_ms = 0
            if end_ms > len(audio):
                end_ms = len(audio)
            if (end_ms - start_ms) < 2000:
                break;
        
            clip = audio[start_ms:end_ms]
            output_file = f"{output_dir}/{audio_file}_splice_{idx}_{i/100}.wav"
            clip.export(output_file, format="wav")
            print(f"Exported clip {idx} to {output_file}")


# Example usage
audio_file = "001-1-5mth-breastfeeding.wav"
labels_file = "001-1-5mth-breastfeeding-labels-vkidwel1.txt"
output_dir = "output_clips"
splice_audio(audio_file, labels_file, output_dir)
# Out:
# Exported clip 0 to output_clips/clip_0_0.0.wav
# Exported clip 0 to output_clips/clip_0_1.0.wav
# Exported clip 0 to output_clips/clip_0_2.0.wav
# Exported clip 0 to output_clips/clip_0_3.0.wav
# Exported clip 0 to output_clips/clip_0_4.0.wav
# Exported clip 0 to output_clips/clip_0_5.0.wav
# Exported clip 0 to output_clips/clip_0_6.0.wav
# Exported clip 0 to output_clips/clip_0_7.0.wav
# Exported clip 0 to output_clips/clip_0_8.0.wav
# Exported clip 0 to output_clips/clip_0_9.0.wav
# Exported clip 0 to output_clips/clip_0_10.0.wav
# Exported clip 0 to output_clips/clip_0_11.0.wav
# Exported clip 0 to output_clips/clip_0_12.0.wav
# Exported clip 0 to output_clips/clip_0_13.0.wav
# Exported clip 0 to output_clips/clip_0_14.0.wav
# Exported clip 0 to output_clips/clip_0_15.0.wav
# Exported clip 0 to output_clips/clip_0_16.0.wav
# Exported clip 0 to output_clips/clip_0_17.0.wav
# Exported clip 0 to output_clips/clip_0_18.0.wav
# Exported clip 0 to output_clips/clip_0_19.0.wav
# Exported clip 0 to output_clips/clip_0_20.0.wav
# Exported clip 1 to output_clips/clip_1_0.0.wav
# Exported clip 1 to output_clips/clip_1_1.0.wav
# Exported clip 1 to output_clips/clip_1_2.0.wav
# Exported clip 1 to output_clips/clip_1_3.0.wav
# Exported clip 1 to output_clips/clip_1_4.0.wav
# Exported clip 1 to output_clips/clip_1_5.0.wav
# Exported clip 1 to output_clips/clip_1_6.0.wav
# Exported clip 1 to output_clips/clip_1_7.0.wav
# Exported clip 1 to output_clips/clip_1_8.0.wav
# Exported clip 1 to output_clips/clip_1_9.0.wav
# Exported clip 1 to output_clips/clip_1_10.0.wav
# Exported clip 1 to output_clips/clip_1_11.0.wav
# Exported clip 1 to output_clips/clip_1_12.0.wav
# Exported clip 1 to output_clips/clip_1_13.0.wav
# Exported clip 1 to output_clips/clip_1_14.0.wav
# Exported clip 1 to output_clips/clip_1_15.0.wav
# Exported clip 1 to output_clips/clip_1_16.0.wav
# Exported clip 1 to output_clips/clip_1_17.0.wav
# Exported clip 1 to output_clips/clip_1_18.0.wav
# Exported clip 1 to output_clips/clip_1_19.0.wav
# Exported clip 1 to output_clips/clip_1_20.0.wav
# Exported clip 2 to output_clips/clip_2_0.0.wav
# Exported clip 2 to output_clips/clip_2_1.0.wav
# Exported clip 2 to output_clips/clip_2_2.0.wav
# Exported clip 2 to output_clips/clip_2_3.0.wav
# Exported clip 2 to output_clips/clip_2_4.0.wav
# Exported clip 2 to output_clips/clip_2_5.0.wav
# Exported clip 2 to output_clips/clip_2_6.0.wav
# Exported clip 2 to output_clips/clip_2_7.0.wav
# Exported clip 2 to output_clips/clip_2_8.0.wav
# Exported clip 2 to output_clips/clip_2_9.0.wav
# Exported clip 2 to output_clips/clip_2_10.0.wav
# Exported clip 2 to output_clips/clip_2_11.0.wav
# Exported clip 2 to output_clips/clip_2_12.0.wav
# Exported clip 2 to output_clips/clip_2_13.0.wav
# Exported clip 2 to output_clips/clip_2_14.0.wav
# Exported clip 2 to output_clips/clip_2_15.0.wav
# Exported clip 2 to output_clips/clip_2_16.0.wav
# Exported clip 2 to output_clips/clip_2_17.0.wav
# Exported clip 2 to output_clips/clip_2_18.0.wav
# Exported clip 2 to output_clips/clip_2_19.0.wav
# Exported clip 2 to output_clips/clip_2_20.0.wav
# Exported clip 3 to output_clips/clip_3_0.0.wav
# Exported clip 3 to output_clips/clip_3_1.0.wav
# Exported clip 3 to output_clips/clip_3_2.0.wav
# Exported clip 3 to output_clips/clip_3_3.0.wav
# Exported clip 3 to output_clips/clip_3_4.0.wav
# Exported clip 3 to output_clips/clip_3_5.0.wav
# Exported clip 3 to output_clips/clip_3_6.0.wav
# Exported clip 3 to output_clips/clip_3_7.0.wav
# Exported clip 3 to output_clips/clip_3_8.0.wav
# Exported clip 3 to output_clips/clip_3_9.0.wav
# Exported clip 3 to output_clips/clip_3_10.0.wav
# Exported clip 3 to output_clips/clip_3_11.0.wav
# Exported clip 3 to output_clips/clip_3_12.0.wav
# Exported clip 3 to output_clips/clip_3_13.0.wav
# Exported clip 3 to output_clips/clip_3_14.0.wav
# Exported clip 3 to output_clips/clip_3_15.0.wav
# Exported clip 3 to output_clips/clip_3_16.0.wav
# Exported clip 3 to output_clips/clip_3_17.0.wav
# Exported clip 3 to output_clips/clip_3_18.0.wav
# Exported clip 3 to output_clips/clip_3_19.0.wav
# Exported clip 3 to output_clips/clip_3_20.0.wav
# Exported clip 4 to output_clips/clip_4_0.0.wav
# Exported clip 4 to output_clips/clip_4_1.0.wav
# Exported clip 4 to output_clips/clip_4_2.0.wav
# Exported clip 4 to output_clips/clip_4_3.0.wav
# Exported clip 4 to output_clips/clip_4_4.0.wav
# Exported clip 4 to output_clips/clip_4_5.0.wav
# Exported clip 4 to output_clips/clip_4_6.0.wav
# Exported clip 4 to output_clips/clip_4_7.0.wav
# Exported clip 4 to output_clips/clip_4_8.0.wav
# Exported clip 4 to output_clips/clip_4_9.0.wav
# Exported clip 4 to output_clips/clip_4_10.0.wav
# Exported clip 4 to output_clips/clip_4_11.0.wav
# Exported clip 4 to output_clips/clip_4_12.0.wav
# Exported clip 4 to output_clips/clip_4_13.0.wav
# Exported clip 4 to output_clips/clip_4_14.0.wav
# Exported clip 4 to output_clips/clip_4_15.0.wav
# Exported clip 4 to output_clips/clip_4_16.0.wav
# Exported clip 4 to output_clips/clip_4_17.0.wav
# Exported clip 4 to output_clips/clip_4_18.0.wav
# Exported clip 4 to output_clips/clip_4_19.0.wav
# Exported clip 4 to output_clips/clip_4_20.0.wav
# Exported clip 5 to output_clips/clip_5_0.0.wav
# Exported clip 5 to output_clips/clip_5_1.0.wav
# Exported clip 5 to output_clips/clip_5_2.0.wav
# Exported clip 5 to output_clips/clip_5_3.0.wav
# Exported clip 5 to output_clips/clip_5_4.0.wav
# Exported clip 5 to output_clips/clip_5_5.0.wav
# Exported clip 5 to output_clips/clip_5_6.0.wav
# Exported clip 5 to output_clips/clip_5_7.0.wav
# Exported clip 5 to output_clips/clip_5_8.0.wav
# Exported clip 5 to output_clips/clip_5_9.0.wav
# Exported clip 5 to output_clips/clip_5_10.0.wav
# Exported clip 5 to output_clips/clip_5_11.0.wav
# Exported clip 5 to output_clips/clip_5_12.0.wav
# Exported clip 5 to output_clips/clip_5_13.0.wav
# Exported clip 5 to output_clips/clip_5_14.0.wav
# Exported clip 5 to output_clips/clip_5_15.0.wav
# Exported clip 5 to output_clips/clip_5_16.0.wav
# Exported clip 5 to output_clips/clip_5_17.0.wav
# Exported clip 5 to output_clips/clip_5_18.0.wav
# Exported clip 5 to output_clips/clip_5_19.0.wav
# Exported clip 5 to output_clips/clip_5_20.0.wav
# Exported clip 6 to output_clips/clip_6_0.0.wav
# Exported clip 6 to output_clips/clip_6_1.0.wav
# Exported clip 6 to output_clips/clip_6_2.0.wav
# Exported clip 6 to output_clips/clip_6_3.0.wav
# Exported clip 6 to output_clips/clip_6_4.0.wav
# Exported clip 6 to output_clips/clip_6_5.0.wav
# Exported clip 6 to output_clips/clip_6_6.0.wav
# Exported clip 6 to output_clips/clip_6_7.0.wav
# Exported clip 6 to output_clips/clip_6_8.0.wav
# Exported clip 6 to output_clips/clip_6_9.0.wav
# Exported clip 6 to output_clips/clip_6_10.0.wav
# Exported clip 6 to output_clips/clip_6_11.0.wav
# Exported clip 6 to output_clips/clip_6_12.0.wav
# Exported clip 6 to output_clips/clip_6_13.0.wav
# Exported clip 6 to output_clips/clip_6_14.0.wav
# Exported clip 6 to output_clips/clip_6_15.0.wav
# Exported clip 6 to output_clips/clip_6_16.0.wav
# Exported clip 6 to output_clips/clip_6_17.0.wav
# Exported clip 6 to output_clips/clip_6_18.0.wav
# Exported clip 6 to output_clips/clip_6_19.0.wav
# Exported clip 6 to output_clips/clip_6_20.0.wav
